# %%
from sqlitesearch import TextSearchIndex

sqlite_index = TextSearchIndex(
    text_fields=['question','section','answer'],
    keyword_fields=['course'],
    #id_field='doc_id',                 #---> use the existing id so if its re-run, it will update existing records instead of creating duplicates
    db_path='llm-faq.db'
)

# %%
len(sqlite_index.search(''))
# Out:
# 0

# %%
from dotenv import load_dotenv
load_dotenv()

from openai import OpenAI
openai_client = OpenAI()

from rag_helper import RAGBase

# %%
from rag_helper import RAGBase
assistant = RAGBase(sqlite_index, openai_client)

# %%
assistant.rag('Why are we not using langchain the llm course?')
#Explain the Open AI errors when running chat completions
#'I just discovered the course, can i join? 
# explain how the certificate name works
# Out:
# 'We’re not using LangChain in the course because we want to first build the core LLM app pieces ourselves: prompting, retrieval, indexing, and evaluation.\n\nThe idea is to learn the fundamentals before relying on a framework—similar to learning HTML, CSS, and JavaScript before using React or Angular.'
