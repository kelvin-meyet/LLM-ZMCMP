# %%
from rag_helper import RAGBase
from ingest import load_faq_data, build_index

# %%
from dotenv import load_dotenv
load_dotenv()  # Load environment variables from .env file

from openai import OpenAI
openai_client = OpenAI()  # Initialize OpenAI client

# %%
documents = load_faq_data()
index = build_index(documents)

assistant = RAGBase(index=index, llm_client=openai_client)

# %%
assistant.rag("What is the purpose of this project?")
# Out:
# 'The purpose of this project is to build an individual capstone project that can be evaluated on its own, with a reproducible setup that others can clone and run using their own credentials.'

# %%
assistant.rag("I just discovered this course, can i join it?")
# Out:
# 'Yes, you can still join the course.\n\nIf you want a certificate, you need to submit your project while submissions are still open.'
