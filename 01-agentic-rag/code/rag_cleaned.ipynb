# %%
from rag_helper import RAGBase
from ingest import load_faq_data, build_index

from dotenv import load_dotenv
load_dotenv()

from openai import OpenAI
openai_client = OpenAI()

# %%
documents = load_faq_data()
index = build_index(documents)   #---> non-persistent index, will be lost when the notebook is closed

assistant = RAGBase(index=index, llm_client=openai_client)

# %%
assistant.rag("when can i join?")
# Out:
# 'Yes, you can still join.\n\nIf you want to receive a certificate, you need to submit your project while submissions are still open.'
